# %% [markdown]
# # AAI614: Data Science & its Applications
#
# ### *Week 3: Practical Exercise with Data Cleaning*
# **Assignment:** Use the dataset from the Mercari Price Suggestion Challenge, and use OpenRefine to clean the data.

# %%
import pandas as pd
import numpy as np

# %%
#offline mode
train_before_clearning = pd.read_csv("before.tsv", sep="\t")
train_after_cleaning   = pd.read_csv("after.tsv",  sep="\t")

print("Before cleaning:", train_before_clearning.shape)
print("After cleaning: ", train_after_cleaning.shape)
# Out:
# Before cleaning: (1482535, 8)
# After cleaning:  (1476208, 13)

# %% [markdown]
# **1. DataStet Before Data Cleaning**

# %%
train_before_clearning.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %% [markdown]
# **2. DataStet After Data Cleaning**

# %%
train_after_cleaning.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name category_name 1  \
# 0                                  Men/Tops/T-shirts             Men
# 1  Electronics/Computers & Tablets/Components & P...     Electronics
# 2                        Women/Tops & Blouses/Blouse           Women
# 3                 Home/Home Décor/Home Décor Accents            Home
# 4                            Women/Jewelry/Necklaces           Women
#
#        category_name 2     category_name 3 brand_name  price  high_priced  \
# ...
